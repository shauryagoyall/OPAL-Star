# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
df = pd.read_csv("./0.monitor.csv")
length = len(df["t"])

axis = [x for x in range(length)]
plt.plot(axis,df["r"])

plt.title("Opal instance 2")
# Out:
# Text(0.5, 1.0, 'Opal instance 2')

# %%
df["t"]
# Out:
# 0            46.785125
# 1            46.996109
# 2            47.216982
# 3            47.833883
# 4            48.078402
#               ...
# 162495    62061.087270
# 162496    62061.395500
# 162497    62061.733220
# 162498    62062.136910
# 162499    62062.549700
# Name: t, Length: 162500, dtype: float64

# %%
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
